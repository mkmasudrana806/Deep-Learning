# %% [markdown]
# ## perceptron optimization using gradient descent

# %%
from sklearn.datasets import make_classification
X, y = make_classification(n_samples=100, n_features=2, n_informative=1, n_redundant=0, n_clusters_per_class=1, random_state=41, n_classes=2, n_repeated=0, hypercube=False, class_sep=15)

print(X[:5], y[:5])
# Out:
# [[ 0.35523945 -0.11697552]
#  [-0.09282829 -0.73115232]
#  [-0.1984984  -0.7081059 ]
#  [-2.44001098 -2.01199214]
#  [-0.0448475   1.63493163]] [1 1 1 0 1]

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
plt.scatter(X[:, 0], X[:, 1], c=y, cmap='winter', s=50)
plt.show()

# %%
def perceptron(X, y):
    w1=w2=b=1
    lr=0.1
    
    for j in range(1000):
        for i in range(X.shape[0]):
            z = w1 * X[i][0] + w2 * X[i][1] + b

            if z*y[i] < 0:
                w1 = w1 + lr * y[i] * X[i][0]
                w2 = w2 + lr * y[i] * X[i][1]
                b = b + lr * y[i]
                
    return w1, w2, b

# %%
w1, w2, b = perceptron(X, y)
print(w1, w2, b)
# Out:
# 1.006638570722407 0.22215119727529098 1.3000000000000003

# %%
m = -(w1 / w2)
c = -(b / w2)
print(m, c)
# Out:
# -4.531321834268464 -5.851870329508209

# %%
import numpy as np
import matplotlib.pyplot as plt

x_input = np.linspace(-3, 3, 100)
y_input = m * x_input + c


plt.figure(figsize=(10, 6))
plt.plot(x_input, y_input, color='red', linewidth=3)
plt.scatter(X[:, 0], X[:, 1], c=y, cmap='winter', s=50)
plt.ylim(-3, 2)
# Out:
# (-3.0, 2.0)

# %% [markdown]
# ## Problem with perceptron
# Perceptron is a mathematical function which work with linear data. can not handle non-linear data.
# use: playground.tensorflow website to visualize the perceptron
